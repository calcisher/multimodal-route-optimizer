# %%
from checkmybus import CheckMyBusClient, CheckMyBusSearchParams

# %%
client = CheckMyBusClient()
result = client.search(CheckMyBusSearchParams(
    departure_location="Munich, Germany",
    departure_date="2026-05-10",
    arrival_location="Nuremberg, Germany",
))

# %%
df = result.to_dataframe()

# %%
df.tail()
# Out:
#            company       operator origin_city       origin_station  dest_city  \
# 124  Deutsche Bahn  Deutsche Bahn      Munich         East Station   Erlangen
# 125  Deutsche Bahn  Deutsche Bahn      Munich         East Station   Erlangen
# 126  Deutsche Bahn  Deutsche Bahn      Munich         East Station   Erlangen
# 127        FlixBus        FlixBus      Munich  Central Bus Station     Fuerth
# 128      BlaBlaCar      BlaBlaCar      Munich    Pelkovenstraße 91  Nuremberg
#
#         dest_station        departure_dt          arrival_dt  duration_min  \
# 124  Central Station 2026-05-10 00:49:00 2026-05-10 06:55:00           366
# 125  Central Station 2026-05-10 21:07:00 2026-05-11 00:26:00           199
# 126  Central Station 2026-05-10 22:09:00 2026-05-11 01:39:00           210
# 127  Central Station 2026-05-10 02:00:00 2026-05-10 04:10:00           130
# 128    Parkplatz TuT 2026-05-10 13:00:00 2026-05-10 14:50:00           110
#
#     duration_str  ...  currency price_formatted transport_mode stops  \
# 124        6h 6m  ...       EUR          €29.19          train     2
# 125       3h 19m  ...       EUR          €29.19          train     2
# 126       3h 30m  ...       EUR          €19.19          train     1
# 127       2h 10m  ...       EUR          €14.98            bus     0
# 128       1h 50m  ...       EUR          €12.29            car     0
#
#      free_seats  seat_class sold_out  deep_link  \
# 124          50     Economy    False       None
# 125          50     Economy    False       None
# 126          50     Economy    False       None
# 127          73     Economy    False       None
# 128          50     Economy    False       None
#
#                                         checkmybus_url      source
# 124  https://www.checkmybus.com/munich/nuremberg?mo...  checkmybus
# 125  https://www.checkmybus.com/munich/nuremberg?mo...  checkmybus
# 126  https://www.checkmybus.com/munich/nuremberg?mo...  checkmybus
# 127  https://www.checkmybus.com/munich/nuremberg?mo...  checkmybus
# 128  https://www.checkmybus.com/munich/nuremberg?mo...  checkmybus
#
# [5 rows x 21 columns]

# %%
df[df['transport_mode']=="train"]
# Out:
#            company       operator origin_city   origin_station  \
# 0    Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 1    Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 2    Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 3    Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 4    Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# ..             ...            ...         ...              ...
# 123  Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 124  Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 125  Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 126  Deutsche Bahn  Deutsche Bahn      Munich  Central Station
# 127  Deutsche Bahn  Deutsche Bahn      Munich  Central Station
#
#              dest_city     dest_station        departure_dt  \
# 0    Frankfurt am Main  Central Station 2026-05-16 00:01:00
# 1    Frankfurt am Main  Central Station 2026-05-16 00:01:00
# 2    Frankfurt am Main  Central Station 2026-05-16 01:59:00
# 3    Frankfurt am Main  Central Station 2026-05-16 01:59:00
# 4    Frankfurt am Main  Central Station 2026-05-16 04:20:00
# ..                 ...              ...                 ...
# 123  Frankfurt am Main    South Station 2026-05-16 06:44:00
# 124  Frankfurt am Main    South Station 2026-05-16 10:19:00
# 125  Frankfurt am Main    South Station 2026-05-16 19:45:00
# 126  Frankfurt am Main    South Station 2026-05-16 19:45:00
# 127  Frankfurt am Main    South Station 2026-05-16 19:45:00
#
#              arrival_dt  duration_min duration_str  ...  currency  \
# 0   2026-05-16 04:38:00           277       4h 37m  ...       EUR
# 1   2026-05-16 04:38:00           277       4h 37m  ...       EUR
# 2   2026-05-16 07:37:00           338       5h 38m  ...       EUR
# 3   2026-05-16 07:37:00           338       5h 38m  ...       EUR
# 4   2026-05-16 07:40:00           200       3h 20m  ...       EUR
# ..                  ...           ...          ...  ...       ...
# 123 2026-05-16 10:23:00           219       3h 39m  ...       EUR
# 124 2026-05-16 13:55:00           216       3h 36m  ...       EUR
# 125 2026-05-16 23:04:00           199       3h 19m  ...       EUR
# 126 2026-05-16 23:04:00           199       3h 19m  ...       EUR
# 127 2026-05-16 23:04:00           199       3h 19m  ...       EUR
#
#     price_formatted transport_mode stops  free_seats   seat_class sold_out  \
# 0            €27.99          train     0          50  First Class    False
# 1            €17.99          train     0          50      Economy    False
# 2            €40.99          train     2          50  First Class    False
# 3            €29.99          train     2          50      Economy    False
# 4            €29.99          train     1          50  First Class    False
# ..              ...            ...   ...         ...          ...      ...
# 123          €37.99          train     1          50      Economy    False
# 124          €39.94          train     2          50      Economy    False
# 125          €78.99          train     1          50  First Class    False
# 126          €67.99          train     1          50      Economy    False
# 127          €67.99          train     1          50      Economy    False
#
#      deep_link                                     checkmybus_url      source
# 0         None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 1         None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 2         None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 3         None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 4         None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# ..         ...                                                ...         ...
# 123       None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 124       None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 125       None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 126       None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
# 127       None  https://www.checkmybus.com/munich/frankfurt-am...  checkmybus
#
# [109 rows x 21 columns]

# %%
df["transport_mode"].unique()
# Out:
# <StringArray>
# ['bus']
# Length: 1, dtype: str

# %%
df
# Out:
#    company operator origin_city       origin_station       dest_city  \
# 0  FlixBus  FlixBus      Munich  Central Bus Station  Venice Airport
# 1  FlixBus  FlixBus      Munich  Central Bus Station  Venice Airport
# 2  FlixBus  FlixBus      Munich  Central Bus Station  Venice Airport
# 3  FlixBus  FlixBus      Munich  Central Bus Station  Venice Airport
# 4  FlixBus  FlixBus      Munich  Central Bus Station        Pitomača
#
#          dest_station        departure_dt          arrival_dt  duration_min  \
# 0      Venice Airport 2026-04-16 03:05:00 2026-04-16 13:45:00           640
# 1      Venice Airport 2026-04-16 08:00:00 2026-04-16 17:15:00           555
# 2      Venice Airport 2026-04-16 13:45:00 2026-04-16 23:55:00           610
# 3      Venice Airport 2026-04-16 23:15:00 2026-04-17 07:40:00           505
# 4  Ul. Ljudevita Gaja 2026-04-16 23:40:00 2026-04-17 10:35:00           655
#
#   duration_str  ...  currency price_formatted transport_mode stops  \
# 0      10h 40m  ...       EUR          €42.47            bus     1
# 1       9h 15m  ...       EUR          €30.98            bus     0
# 2      10h 10m  ...       EUR          €42.47            bus     1
# 3       8h 25m  ...       EUR          €41.98            bus     0
# 4      10h 55m  ...       EUR          €31.98            bus     0
#
#    free_seats  seat_class sold_out  deep_link  \
# 0          62     Economy    False       None
# 1          70     Economy    False       None
# 2          35     Economy    False       None
# 3          50     Economy    False       None
# 4          67     Economy    False       None
#
#                                       checkmybus_url      source
# 0  https://www.checkmybus.com/munich/venice-airpo...  checkmybus
# 1  https://www.checkmybus.com/munich/venice-airpo...  checkmybus
# 2  https://www.checkmybus.com/munich/venice-airpo...  checkmybus
# 3  https://www.checkmybus.com/munich/venice-airpo...  checkmybus
# 4  https://www.checkmybus.com/munich/venice-airpo...  checkmybus
#
# [5 rows x 21 columns]
